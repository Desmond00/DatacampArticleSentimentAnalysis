# %% [markdown]
# In this notebook, we will attempt to apply another type of text-data preprocessing viz. TF-IDF based vectorization. We will also try a simple neural network model to see if we can improve the baseline score.
#
# We could have gone for sequence models by incorporating word embeddings but the corpus that we are dealing with is not very large and experiments say that in these cases n-gram models perform better. Another reason behind not using word embeddings is embedding relationships are learned in dense space, and this happens best over many samples (i.e. a very very large corpora).

# %%
#Dependencies
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

from tensorflow.python.keras import models
from tensorflow.python.keras.layers import Dense
from tensorflow.python.keras.layers import Dropout

from keras import backend as K

import tensorflow as tf 
# import tf.keras

# Importing the keras libraries from tensorflow package for maintaining same library use for loading the saved model
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import CustomObjectScope
from tensorflow.keras.initializers import glorot_uniform

from sklearn.feature_extraction.text import TfidfVectorizer

import matplotlib.pyplot as plt
# %matplotlib inline
# We are using tensorflow version 2.0.0-beta0, to allow tensorflow some operations of v1
import tensorflow.compat.v1 as tfv1
tfv1.disable_v2_behavior()

from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

import warnings
warnings.filterwarnings("ignore")
# Out:
# d:\programfiles\anaconda\envs\nlp\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# d:\programfiles\anaconda\envs\nlp\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# d:\programfiles\anaconda\envs\nlp\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# d:\programfiles\anaconda\envs\nlp\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# d:\programfiles\anaconda\envs\nlp\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# d:\programfiles\anaconda\envs\nlp\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# d:\programfiles\anaconda\envs\nlp\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# d:\programfiles\anaconda\envs\nlp\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# d:\programfiles\anaconda\envs\nlp\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# d:\programfiles\anaconda\envs\nlp\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# d:\programfiles\anaconda\envs\nlp\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# d:\programfiles\anaconda\envs\nlp\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.
# WARNING: Logging before flag parsing goes to stderr.
# W0905 04:53:49.761488  3984 deprecation.py:323] From d:\programfiles\anaconda\envs\nlp\lib\site-packages\tensorflow\python\compat\v2_compat.py:65: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %% [markdown]
# During our previous experiments, we serialized the shorter versions of the train and test sets. Let's load them.

# %%
new_train_frame = pd.read_csv('./OriginalPlusGeneratedData.csv')

# %%
new_train_frame.drop(new_train_frame[new_train_frame['label'].isna()==True].index, axis=0, inplace=True)

# %%
new_train_frame.head()
# Out:
#                                              comment  label
# 0  Really nice tutorial - However I am having iss...    0.0
# 1    you need to have pip and setuptools installe...    1.0
# 2  thank you so much for this great tutorial.  I ...    0.0
# 3             Thank you very much. Very nice article    0.0
# 4  Codecademy is a decent place to begin in the e...    1.0

# %% [markdown]
# ## First let's confirm with the class label's uniqueness

# %%
np.unique(new_train_frame['label'])
# Out:
# array([0., 1.])

# %% [markdown]
# ## Now let's check on the class distribution

# %%
classSpam = new_train_frame[new_train_frame.label == 1.0]
classNonSpam = new_train_frame[new_train_frame.label == 0.0]

# %%
classSpam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 311 entries, 1 to 805
# Data columns (total 2 columns):
# comment    311 non-null object
# label      311 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 7.3+ KB

# %%
classNonSpam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 497 entries, 0 to 807
# Data columns (total 2 columns):
# comment    497 non-null object
# label      497 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 11.6+ KB

# %% [markdown]
# #### So the distribution is 111:497 for spam vs non-spam, abbreviates to 1:5.

# %% [markdown]
# ## Splitting into train and validation sets (80:20) -

# %%
X_train, X_valid, y_train, y_valid = train_test_split(new_train_frame['comment'], new_train_frame['label'], \
                                                    test_size=0.2, random_state=42)

# %% [markdown]
# ## Data preprocessing with TF-IDF vectorization -
#
# We can write utility functions for this which in turns gives our code a modular approach.

# %%
# Vectorization parameters
# Range (inclusive) of n-gram sizes for tokenizing text.
NGRAM_RANGE = (1, 2)

# Whether text should be split into word or character n-grams.
# One of 'word', 'char'.
TOKEN_MODE = 'word'

# Minimum document/corpus frequency below which a token will be discarded.
MIN_DOCUMENT_FREQUENCY = 2

def ngram_vectorize(train_texts, train_labels, val_texts):
    """
    # Arguments
        train_texts: list, training text strings.
        train_labels: np.ndarray, training labels.
        val_texts: list, validation text strings.

    # Returns
        x_train, x_val: vectorized training and validation texts
    """
    # Create keyword arguments to pass to the 'tf-idf' vectorizer.
    kwargs = {
            'ngram_range': NGRAM_RANGE,  # Use 1-grams + 2-grams.
            'dtype': 'int32',
            'strip_accents': 'unicode',
            'decode_error': 'replace',
            'analyzer': TOKEN_MODE,  # Split text into word tokens.
            'min_df': MIN_DOCUMENT_FREQUENCY,
    }
    vectorizer = TfidfVectorizer(**kwargs)


    # Learn vocabulary from training texts and vectorize training texts.
    x_train = vectorizer.fit_transform(train_texts)

    # Vectorize validation texts.
    x_val = vectorizer.transform(val_texts)
    
    # Show extracted features
    cache = {}
    cache['extractedFeatures'] = vectorizer.get_feature_names()
    
    return x_train, x_val, vectorizer, cache

# %% [markdown]
# ## Building an MLP model

# %% [markdown]
# We are dealing with a binary classification problem so the activation function for the output layer of the network will be `sigmoid` as it will give us the class probabilities which we can eventually convert to discrete classes.
#
# The following function `get_last_layer_units_and_activation()` is responsible for -
# * Determining the activation function for the output layer.
# * Number of units to be present in the output layer.
#
# The function can also be extended to multinomial classification tasks as well (where `softmax` activation function is used in the last layer).

# %%
def get_last_layer_units_and_activation(num_classes):
    """Gets the # units and activation function for the last network layer.

    # Arguments
        num_classes: int, number of classes.

    # Returns
        units, activation values.
    """
    if num_classes == 2:
        activation = 'sigmoid'
        units = 1
    else:
        activation = 'softmax'
        units = num_classes
    return units, activation

# %% [markdown]
# The following method builds us a feed-forward network.

# %%
def mlp_model(layers, units, dropout_rate, input_shape, num_classes):
    """Creates an instance of a multi-layer perceptron model.

    # Arguments
        layers: int, number of `Dense` layers in the model.
        units: int, output dimension of the layers.
        dropout_rate: float, percentage of input to drop at Dropout layers.
        input_shape: tuple, shape of input to the model.
        num_classes: int, number of output classes.

    # Returns
        An MLP model instance.
    """
    op_units, op_activation = get_last_layer_units_and_activation(num_classes)
    model = models.Sequential()
    model.add(Dropout(rate=dropout_rate, input_shape=input_shape))

    for _ in range(layers-1):
        model.add(Dense(units=units, activation='relu'))
        model.add(Dropout(rate=dropout_rate))

    model.add(Dense(units=op_units, activation=op_activation))
    return model

# %% [markdown]
# `train_ngram_model()` function helps to train and validate our shallow network.

# %% [markdown]
# ## Before going for training adding F1-score custom metrics for evalutaion

# %%
def f1(y_true, y_pred):
    def recall(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

    def precision(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

    precision = precision(y_true, y_pred)
    recall = recall(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
def train_ngram_model(data,
                      learning_rate=1e-3,
                      epochs=1000,
                      batch_size=128,
                      layers=3,
                      units=64,
                      dropout_rate=0.2):
    # Get the data.
    (train_texts, train_labels), (val_texts, val_labels) = data

    # Specify the number of classes.
    num_classes = 2

    # Vectorize texts.
    x_train, x_val, vectorizer, cache = ngram_vectorize(
        train_texts, train_labels, val_texts)

    # Instantiate the model
    model = mlp_model(layers=layers,
                                  units=units,
                                  dropout_rate=dropout_rate,
                                  input_shape=x_train.shape[1:],
                                  num_classes=num_classes)

    # Compile model with learning parameters.
    loss = 'binary_crossentropy'
    optimizer = tf.keras.optimizers.Adam(lr=learning_rate)
    model.compile(optimizer=optimizer, loss=loss, metrics=['acc', f1])

    # Create callback for early stopping on validation loss. If the loss does
    # not decrease in two consecutive tries, stop training.
    # Tensorboard callback for debugging purpose
    callbacks = [tf.keras.callbacks.EarlyStopping(
        monitor='val_loss', patience=2), tf.keras.callbacks.TensorBoard(log_dir='./logs')]

    # Train and validate model.
    history = model.fit(
            x_train,
            train_labels,
            epochs=epochs,
            callbacks=callbacks,
            validation_data=(x_val, val_labels),
            verbose=2,  # Logs once per epoch.
            batch_size=batch_size)

    # Print results.
    history = history.history
    print('Validation accuracy: {acc}, loss: {loss}'.format(
            acc=history['val_acc'][-1], loss=history['val_loss'][-1]))

    # Save model.
    model.save('zs_mlp_model.h5')
    return history

# %% [markdown]
# <b>A note on the model configuration choices</b>:
# * **Dropout layers**: For reducing overfitting. Its value is set 0.2 which means that 20% of the input data will be randomly chosen and excluded from successive activations. This [blog](https://machinelearningmastery.com/how-to-reduce-overfitting-with-dropout-regularization-in-keras/) provides a gentle introduction to dropout regularization.
# * **Loss function**: We used `binary_crossentropy` as our loss function which is a pretty standard one when it comes to binary classification. It is also convex in nature which in turn helps the optimization algorithm in a faster convergence.
# * **Adam optimizer**: Stochastic gradient descent maintains a single learning rate (termed alpha) for all weight updates and the learning rate does not change during training.Whereas in Adam, a learning rate is maintained for each network weight (parameter) and separately adapted as learning unfolds.The method computes individual adaptive learning rates for different parameters from estimates of first and second moments of the gradients.

# %% [markdown]
# ## Training and evaluating the MLP model

# %% [markdown]
# #### Preparing the data for fitting it to a feed-forward network -

# %%
data = ((list(X_train), np.array(y_train)), (list(X_valid), np.array(y_valid)))

# %% [markdown]
# #### Training a feed-forward networks -

# %%
x_train, x_val, vectorizer, cache = ngram_vectorize(
        X_train, y_train, X_valid)

# %% [markdown]
# ## Let's check the tokens

# %%
cache
# Out:
# {'extractedFeatures': ['000',
#   '00000',
#   '041',
#   '041 8324',
#   '10',
#   '10 or',
#   '100',
#   '100 times',
#   '11',
#   '12',
#   '123',
#   '123movies',
#   '123movies and',
#   '123moviescounte',
#   '123moviescounte xyz',
#   '15',
#   '20',
#   '2018',
#   '2019',
#   '24',
#   '24 24',
#   '24 issues',
#   '24 printer',
#   '24 support',
#   '24 technical',
#   '28',
#   '28 28',
#   '2d',
#   '30',
#   '32',
#   '365',
#   '44',
#   '44 800',
#   '462',
#   '462 in',
#   '50',
#   '50 support',
#   '500',
#   '500 apple',
#   '64',
#   '800',
#   '800 customer',
#   '800 phone',
#   '8324',
#   '888',
#   '8884800288',
#   '8884800288 uk',
#   '98',
#   '__init__',
#   '__init__ self',
#   '_prices',
#   'able',
#   'able to',
#   'about',
#   'about anything',
#   'about how',
#   'about sharing',
#   'about the',
#   'about this',
#   'about usps',
#   'about would',
#   'above',
#   'access',
#   'access postalexperience',
#   'account',
#   'accounting',
#   'accuracy',
#   'achieve',
#   'acknowledge',
#   'across',
#   'across the',
#   'active',
#   'active 24',
#   'actual',
#   'actually',
#   'add',
#   'add of',
#   'added',
#   'adding',
#   'adding my',
#   'addition',
#   'addition good',
#   'additional',
#   'additional information',
#   'address',
#   'advance',
#   'african',
#   'african wear',
#   'after',
#   'after executing',
#   'after reading',
#   'after the',
#   'again',
#   'again have',
#   'against',
#   'against pointless',
#   'age',
#   'agency',
#   'agency of',
#   'ahead',
#   'ai',
#   'airlines',
#   'airlines customer',
#   'airlines for',
#   'airlines free',
#   'airlines grab',
#   'airlines off',
#   'airlines official',
#   'airlines phone',
#   'airlines reservations',
#   'airlines why',
#   'alexisp',
#   'algorithm',
#   'all',
#   'all all',
#   'all india',
#   'all parts',
#   'all thanks',
#   'all the',
#   'all these',
#   'all your',
#   'allegiant',
#   'allegiant airlines',
#   'allows',
#   'almost',
#   'alot',
#   'alot for',
#   'already',
#   'also',
#   'also data',
#   'also have',
#   'also online',
#   'also want',
#   'alternative',
#   'alternative to',
#   'always',
#   'always current',
#   'always loving',
#   'am',
#   'am adding',
#   'am doing',
#   'am getting',
#   'am having',
#   'am installing',
#   'am looking',
#   'am lost',
#   'am new',
#   'am not',
#   'am stuck',
#   'am trying',
#   'am wondering',
#   'am working',
#   'amazing',
#   'amazing post',
#   'amazing tutorial',
#   'american',
#   'american airlines',
#   'an',
#   'an amazing',
#   'an error',
#   'an interesting',
#   'an issue',
#   'an mac',
#   'an machine',
#   'anaconda',
#   'analysis',
#   'and',
#   'and acknowledge',
#   'and after',
#   'and always',
#   'and am',
#   'and and',
#   'and are',
#   'and bolts',
#   'and check',
#   'and chennai',
#   'and code',
#   'and compute',
#   'and connect',
#   'and could',
#   'and deals',
#   'and dedication',
#   'and easy',
#   'and enjoy',
#   'and for',
#   'and found',
#   'and get',
#   'and got',
#   'and great',
#   'and guide',
#   'and have',
#   'and how',
#   'and if',
#   'and import',
#   'and in',
#   'and informative',
#   'and international',
#   'and it',
#   'and its',
#   'and learned',
#   'and more',
#   'and not',
#   'and offers',
#   'and one',
#   'and or',
#   'and plot',
#   'and python',
#   'and reinstall',
#   'and see',
#   'and setuptools',
#   'and simple',
#   'and so',
#   'and store',
#   'and thanks',
#   'and the',
#   'and then',
#   'and this',
#   'and ve',
#   'and very',
#   'and well',
#   'and what',
#   'and writing',
#   'and wrong',
#   'and you',
#   'another',
#   'answer',
#   'antivirus',
#   'antivirus get',
#   'antivirus support',
#   'any',
#   'any chance',
#   'any discounts',
#   'any document',
#   'any help',
#   'any idea',
#   'any kind',
#   'any one',
#   'any product',
#   'any queries',
#   'any suggestion',
#   'any there',
#   'any type',
#   'any way',
#   'anyone',
#   'anyone face',
#   'anyone still',
#   'anything',
#   'anything due',
#   'anytime',
#   'anyway',
#   'anywhere',
#   'api',
#   'app',
#   'apple',
#   'apple store',
#   'application',
#   'applied',
#   'apply',
#   'apply this',
#   'appreciate',
#   'appreciate your',
#   'approach',
#   'are',
#   'are available',
#   'are discounts',
#   'are doing',
#   'are facing',
#   'are forced',
#   'are have',
#   'are not',
#   'are real',
#   'are really',
#   'are struggling',
#   'are the',
#   'are there',
#   'are they',
#   'are thinking',
#   'are trying',
#   'are using',
#   'are very',
#   'are you',
#   'argument',
#   'arguments',
#   'around',
#   'around the',
#   'array',
#   'array with',
#   'arrays',
#   'arrive',
#   'article',
#   'article and',
#   'article had',
#   'article have',
#   'article https',
#   'article in',
#   'article is',
#   'article its',
#   'article thank',
#   'article very',
#   'article was',
#   'article you',
#   'articles',
#   'as',
#   'as an',
#   'as input',
#   'as inputs',
#   'as it',
#   'as pd',
#   'as the',
#   'as well',
#   'as you',
#   'assistance',
#   'assitance',
#   'assitance call',
#   'at',
#   'at all',
#   'at american',
#   'at delta',
#   'at least',
#   'at step',
#   'at the',
#   'at this',
#   'australia',
#   'australia support',
#   'author',
#   'authorized',
#   'authorized apple',
#   'automatically',
#   'available',
#   'avast',
#   'avast antivirus',
#   'avast customer',
#   'average',
#   'average loss',
#   'avg',
#   'avg antivirus',
#   'avg customer',
#   'avinash',
#   'avoid',
#   'aware',
#   'aware of',
#   'away',
#   'away to',
#   'awesome',
#   'aws',
#   'back',
#   'back stail',
#   'backup',
#   'backup or',
#   'bad',
#   'bars',
#   'based',
#   'based on',
#   'basically',
#   'basics',
#   'basics of',
#   'batch_size',
#   'bayes',
#   'be',
#   'be able',
#   'be back',
#   'be friends',
#   'be great',
#   'be in',
#   'be rather',
#   'be reached',
#   'be the',
#   'be used',
#   'be very',
#   'because',
#   'because it',
#   'because of',
#   'because together',
#   'become',
#   'been',
#   'been looking',
#   'been using',
#   'been working',
#   'before',
#   'begin',
#   'begin in',
#   'beginner',
#   'beginning',
#   'being',
#   'being offered',
#   'believe',
#   'believe that',
#   'believe you',
#   'below',
#   'below error',
#   'besanttechnologies',
#   'best',
#   'best content',
#   'best discounts',
#   'best help',
#   'best information',
#   'best offers',
#   'best post',
#   'best price',
#   'best prices',
#   'best range',
#   'best series',
#   'best tutorial',
#   'best way',
#   'better',
#   'better can',
#   'between',
#   'bi',
#   'bias',
#   'big',
#   'binary',
#   'bing',
#   'bing history',
#   'bit',
#   'bitdefender',
#   'bitdefender antivirus',
#   'bitdefender customer',
#   'blog',
#   'blog me',
#   'blog realize',
#   'blog want',
#   'blog with',
#   'blue',
#   'blue lines',
#   'boggling',
#   'boggling information',
#   'bolts',
#   'bolts watch',
#   'bom',
#   'book',
#   'book cheap',
#   'booking',
#   'booking online',
#   'booking support',
#   'both',
#   'both domestic',
#   'both the',
#   'bottom',
#   'box',
#   'browser',
#   'browser to',
#   'buddy',
#   'buddy buddy',
#   'bug',
#   'build',
#   'building',
#   'bunch',
#   'bunch of',
#   'business',
#   'businesses',
#   'businesses in',
#   'but',
#   'but am',
#   'but better',
#   'but can',
#   'but how',
#   'but if',
#   'but in',
#   'but information',
#   'but it',
#   'but not',
#   'but now',
#   'but still',
#   'but that',
#   'but the',
#   'but then',
#   'but when',
#   'by',
#   'by minmaxscaler',
#   'by one',
#   'by the',
#   'by then',
#   'by your',
#   'by β0',
#   'ca',
#   'cake',
#   'cake group',
#   'calculate',
#   'calculate the',
#   'call',
#   'call at',
#   'call last',
#   'call on',
#   'call phone',
#   'call us',
#   'called',
#   'campaign',
#   'campaign is',
#   'can',
#   'can anyone',
#   'can be',
#   'can display',
#   'can figure',
#   'can get',
#   'can if',
#   'can one',
#   'can python',
#   'can show',
#   'can understand',
#   'can use',
#   'can visit',
#   'can we',
#   'can you',
#   'canada',
#   'canada 8884800288',
#   'cannot',
#   'canon',
#   'canon printer',
#   'capstone',
#   'capstone project',
#   'cards',
#   'cards outs',
#   'care',
#   'care phone',
#   'care toll',
#   'carlo',
#   'carlo for',
#   'carrier',
#   'carrier in',
#   'case',
#   'case of',
#   'cat',
#   'categorical',
#   'categorical variables',
#   'ce',
#   'ce tutoriel',
#   'cell',
#   'center',
#   'chains',
#   'chainsaw',
#   'chainsaw helmet',
#   'chance',
#   'change',
#   'change the',
#   'changed',
#   'changes',
#   'changes the',
#   'character',
#   'cheap',
#   'cheap flight',
#   'check',
#   'check_array',
#   'check_array context',
#   'cheers',
#   'chennai',
#   'chennai in',
#   'chennai you',
#   'choose',
#   'churn',
#   'clarify',
#   'class',
#   'classification',
#   'classifier',
#   'cleaning',
#   'clear',
#   'clear and',
#   'click',
#   'click here',
#   'client',
#   'close',
#   'cloud',
#   'cltv',
#   'cltv in',
#   'cluster',
#   'clustering',
#   'clustering is',
#   'clusters',
#   'cnn',
#   'cnn and',
#   'code',
#   'code above',
#   'code and',
#   'code for',
#   'code in',
#   'code is',
#   'code it',
#   'code should',
#   'code to',
#   'code was',
#   'code you',
#   'codecademy',
#   'codecademy is',
#   'codes',
#   'coding',
#   'coding function',
#   'coding functions',
#   'color',
#   'color of',
#   'column',
#   'columns',
#   'columns for',
#   'com',
#   'com products',
#   'com python',
#   'com watch',
#   'combination',
#   'combination of',
#   'come',
#   'comes',
#   'comes to',
#   'coming',
#   'command',
#   'commitment',
#   'commitment to',
#   'community',
#   'company',
#   'compare',
#   'compared',
#   'comprehension',
#   'comprehension of',
#   'comprehensive',
#   'comprehensive resources',
#   'compute',
#   'compute the',
#   'computer',
#   'computer doesn',
#   'computer how',
#   'computer to',
#   'concept',
#   'condition',
#   'confuse',
#   'confused',
#   'congratulations',
#   'congratulations debbie',
#   'connect',
#   'connect hp',
#   'connect try',
#   'connecting',
#   'consider',
#   'considered',
#   'considering',
#   'consistent',
#   'consistently',
#   'consistently access',
#   'consistently totally',
#   'contact',
#   'content',
#   'content here',
#   'context',
#   'context valueerror',
#   'continue',
#   'continuous',
#   'contrast',
#   'contrib',
#   'contrib rnn',
#   'convert',
#   'convert any',
#   'convert the',
#   'cookie',
#   'cool',
#   'cool thank',
#   'core',
#   'core of',
#   'correct',
#   'correctly',
#   'could',
#   'could be',
#   'could share',
#   'could you',
#   'course',
#   'courses',
#   'create',
#   'created',
#   'creating',
#   'creating style',
#   'creating the',
#   'cross',
#   'cross validation',
#   'csv',
#   'csv file',
#   'current',
#   'current in',
#   'currently',
#   'curve',
#   'curve is',
#   'custom',
#   'customer',
#   'customer care',
#   'customer service',
#   'customer support',
#   'dan',
#   'dash',
#   'dash plot',
#   'data',
#   'data any',
#   'data campaign',
#   'data frame',
#   'data from',
#   'data into',
#   'data issue',
#   'data issues',
#   'data like',
#   'data out',
#   'data science',
#   'data scientists',
#   'data set',
#   'data to',
#   'data train',
#   'data14',
#   'database',
#   'database php',
#   'datacamp',
#   'dataframe',
#   'datalab',
#   'dataset',
#   'dataset for',
#   'dataset which',
#   'dataset with',
#   'datasets',
#   'date',
#   'date time',
#   'day',
#   'days',
#   'de',
#   'dealing',
#   'dealing with',
#   'deals',
#   'deals on',
#   'dear',
#   'debbie',
#   'decent',
#   'decent place',
#   'decide',
#   'decision',
#   'dedication',
#   'dedication with',
#   'deep',
#   'deep learning',
#   'def',
#   'def __init__',
#   'def generate_signals',
#   'defined',
#   'definitely',
#   'definitive',
#   'definitive guide',
#   'delete',
#   'delete bing',
#   'delta',
#   'delta airlines',
#   'delta provides',
#   'description',
#   'design',
#   'design pakistan',
#   'detail',
#   'detailed',
#   'detailed description',
#   'details',
#   'develop',
#   'device',
#   'device then',
#   'df',
#   'dial',
#   'dial american',
#   'dial delta',
#   'dial help',
#   'dial kaspersky',
#   'dial the',
#   'did',
#   'did you',
#   'didn',
#   'difference',
#   'different',
#   'difficulty',
#   'direction',
#   'directory',
#   'disable',
#   'disable email',
#   'discounts',
#   'discounts and',
#   'discounts on',
#   'disk',
#   'display',
#   'display the',
#   'distance',
#   'distribution',
#   'do',
#   'do get',
#   'do give',
#   'do it',
#   'do not',
#   'do the',
#   'do this',
#   'do we',
#   'do with',
#   'do you',
#   'document',
#   'document from',
#   'documentation',
#   'does',
#   'does it',
#   'does not',
#   'doesn',
#   'doesn have',
#   'doesn look',
#   'doing',
#   'doing the',
#   'domestic',
#   'domestic and',
#   'don',
#   'don know',
#   'don understand',
#   'done',
#   'doubt',
#   'doubt that',
#   'down',
#   'download',
#   'download install',
#   'dtype',
#   'due',
#   'due to',
#   'each',
#   'each sample',
#   'easier',
#   'easily',
#   'easily in',
#   'easy',
#   'easy to',
#   'eat',
#   'eat cake',
#   'eat tcake',
#   'eda',
#   'education',
#   'effective',
#   'effort',
#   'either',
#   'element',
#   'elements',
#   'elif',
#   'else',
#   'else statements',
#   'email',
#   'email login',
#   'email signature',
#   'emily',
#   'emily hp',
#   'employee',
#   'employees',
#   'encoded',
#   'encoded what',
#   'encoding',
#   'end',
#   'engine',
#   'enjoy',
#   'enjoy it',
#   'enjoyed',
#   'enough',
#   'enough the',
#   'environment',
#   'error',
#   'error 500',
#   'error at',
#   'error code',
#   'error in',
#   'error message',
#   'error while',
#   'errors',
#   'especially',
#   'estimator',
#   'etc',
#   'etc since',
#   'euclidean',
#   'euclidean distance',
#   'evaluation',
#   'even',
#   'even though',
#   'even when',
#   'eventually',
#   'eventually go',
#   'ever',
#   'every',
#   'exactly',
#   'exale',
#   'exale hope',
#   'example',
#   'example have',
#   'example in',
#   'example of',
#   'examples',
#   'excel',
#   'excel and',
#   'excel even',
#   'excel for',
#   'excel is',
#   'excel spreadsheets',
#   'excel tutorial',
#   'excel with',
#   'excellent',
#   'excellent article',
#   'excellent tutorial',
#   'exciting',
#   'exclusive',
#   'exclusive formula',
#   'exclusive offers',
#   'execute',
#   'executing',
#   'exiting',
#   'expect',
#   'expected',
#   'expecting',
#   'experience',
#   'experienced',
#   'expert',
#   'expert tackle',
#   'experts',
#   'experts canon',
#   'experts experts',
#   'experts will',
#   'explain',
#   'explain the',
#   'explain what',
#   'explained',
#   'explaining',
#   'explanation',
#   'explore',
#   'expressions',
#   'extremely',
#   'extremely easy',
#   'face',
#   'face printer',
#   'facing',
#   'facing here',
#   'factor',
#   'failed',
#   'failed but',
#   'failed to',
#   'failed with',
#   'failure',
#   'false',
#   'familiar',
#   'familiar with',
#   'family',
#   'fantastic',
#   'far',
#   'fashion',
#   'fast',
#   'feature',
#   'features',
#   'features like',
#   'few',
#   'fftrees',
#   'field',
#   'figure',
#   'file',
#   'file home',
#   'files',
#   'filter',
#   'final',
#   'finance',
#   'find',
#   'find the',
#   'finding',
#   'finding are',
#   'finding the',
#   'finished',
#   'finished predictions',
#   'first',
#   'first example',
#   'first of',
#   'firstly',
#   'fit',
#   'fix',
#   'fix it',
#   'fixed',
#   'flight',
#   'flight tickets',
#   'flights',
#   'flights booking',
#   'follow',
#   'follow you',
#   'followed',
#   'followed for',
#   'following',
#   'following line',
#   'following message',
#   'for',
#   'for 10',
#   'for all',
#   'for also',
#   'for always',
#   'for am',
#   'for and',
#   'for any',
#   'for avg',
#   'for download',
#   'for each',
#   'for example',
#   'for few',
#   'for further',
#   'for help',
#   'for in',
#   'for li',
#   'for loop',
#   'for loops',
#   'for many',
#   'for me',
#   'for more',
#   'for multiple',
#   'for my',
#   'for payment',
#   'for posting',
#   ...]}

# %%
h = train_ngram_model(data,\
                      learning_rate=1e-3,\
                      epochs=1000,\
                      batch_size=128,\
                      layers=3,\
                      units=64,\
                      dropout_rate=0.7)
# Out:
# W0905 04:53:50.258161  3984 nn_ops.py:4220] Large dropout rate: 0.7 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# W0905 04:53:50.302083  3984 nn_ops.py:4220] Large dropout rate: 0.7 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# W0905 04:53:50.344928  3984 nn_ops.py:4220] Large dropout rate: 0.7 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# W0905 04:53:50.463614  3984 deprecation.py:323] From d:\programfiles\anaconda\envs\nlp\lib\site-packages\tensorflow\python\ops\nn_impl.py:182: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 646 samples, validate on 162 samples
# Epoch 1/1000
# 646/646 - 1s - loss: 0.6943 - acc: 0.5046 - f1: 0.3136 - val_loss: 0.6872 - val_acc: 0.6235 - val_f1: 0.0000e+00
# Epoch 2/1000
# 646/646 - 0s - loss: 0.6845 - acc: 0.5867 - f1: 0.2949 - val_loss: 0.6815 - val_acc: 0.6235 - val_f1: 0.0000e+00
# Epoch 3/1000
# 646/646 - 0s - loss: 0.6773 - acc: 0.6269 - f1: 0.2645 - val_loss: 0.6762 - val_acc: 0.6235 - val_f1: 0.0000e+00
# Epoch 4/1000
# 646/646 - 0s - loss: 0.6777 - acc: 0.6192 - f1: 0.2699 - val_loss: 0.6705 - val_acc: 0.6235 - val_f1: 0.0000e+00
# Epoch 5/1000
# 646/646 - 0s - loss: 0.6667 - acc: 0.6254 - f1: 0.1833 - val_loss: 0.6636 - val_acc: 0.6235 - val_f1: 0.0000e+00
# Epoch 6/1000
# 646/646 - 0s - loss: 0.6678 - acc: 0.6254 - f1: 0.1383 - val_loss: 0.6553 - val_acc: 0.6235 - val_f1: 0.0000e+00
# Epoch 7/1000
# 646/646 - 0s - loss: 0.6553 - acc: 0.6393 - f1: 0.1515 - val_loss: 0.6444 - val_acc: 0.6235 - val_f1: 0.0000e+00
# Epoch 8/1000
# 646/646 - 0s - loss: 0.6405 - acc: 0.6440 - f1: 0.2390 - val_loss: 0.6300 - val_acc: 0.6235 - val_f1: 0.0000e+00
# Epoch 9/1000
# 646/646 - 0s - loss: 0.6337 - acc: 0.6362 - f1: 0.1277 - val_loss: 0.6134 - val_acc: 0.6235 - val_f1: 0.0000e+00
# Epoch 10/1000
# 646/646 - 0s - loss: 0.6222 - acc: 0.6471 - f1: 0.1464 - val_loss: 0.5946 - val_acc: 0.6667 - val_f1: 0.1799
# Epoch 11/1000
# 646/646 - 0s - loss: 0.6082 - acc: 0.6687 - f1: 0.2833 - val_loss: 0.5742 - val_acc: 0.6975 - val_f1: 0.2929
# Epoch 12/1000
# 646/646 - 0s - loss: 0.5816 - acc: 0.6950 - f1: 0.3804 - val_loss: 0.5516 - val_acc: 0.7407 - val_f1: 0.4462
# Epoch 13/1000
# 646/646 - 0s - loss: 0.5572 - acc: 0.7105 - f1: 0.4585 - val_loss: 0.5256 - val_acc: 0.7778 - val_f1: 0.5780
# Epoch 14/1000
# 646/646 - 0s - loss: 0.5411 - acc: 0.7415 - f1: 0.4265 - val_loss: 0.4973 - val_acc: 0.8210 - val_f1: 0.6671
# Epoch 15/1000
# 646/646 - 0s - loss: 0.5127 - acc: 0.7647 - f1: 0.4761 - val_loss: 0.4680 - val_acc: 0.8333 - val_f1: 0.6914
# Epoch 16/1000
# 646/646 - 0s - loss: 0.4921 - acc: 0.7879 - f1: 0.6813 - val_loss: 0.4381 - val_acc: 0.8704 - val_f1: 0.8097
# Epoch 17/1000
# 646/646 - 0s - loss: 0.4548 - acc: 0.8189 - f1: 0.5869 - val_loss: 0.4072 - val_acc: 0.8889 - val_f1: 0.7955
# Epoch 18/1000
# 646/646 - 0s - loss: 0.4537 - acc: 0.8096 - f1: 0.5703 - val_loss: 0.3782 - val_acc: 0.8951 - val_f1: 0.8308
# Epoch 19/1000
# 646/646 - 0s - loss: 0.4144 - acc: 0.8313 - f1: 0.7685 - val_loss: 0.3501 - val_acc: 0.9012 - val_f1: 0.8521
# Epoch 20/1000
# 646/646 - 0s - loss: 0.3859 - acc: 0.8700 - f1: 0.6777 - val_loss: 0.3228 - val_acc: 0.9074 - val_f1: 0.8588
# Epoch 21/1000
# 646/646 - 0s - loss: 0.3690 - acc: 0.8870 - f1: 0.8628 - val_loss: 0.2964 - val_acc: 0.9012 - val_f1: 0.8337
# Epoch 22/1000
# 646/646 - 0s - loss: 0.3476 - acc: 0.8746 - f1: 0.7873 - val_loss: 0.2721 - val_acc: 0.9074 - val_f1: 0.8602
# Epoch 23/1000
# 646/646 - 0s - loss: 0.3161 - acc: 0.8994 - f1: 0.8762 - val_loss: 0.2516 - val_acc: 0.9074 - val_f1: 0.8832
# Epoch 24/1000
# 646/646 - 0s - loss: 0.2884 - acc: 0.9087 - f1: 0.8729 - val_loss: 0.2331 - val_acc: 0.9198 - val_f1: 0.9101
# Epoch 25/1000
# 646/646 - 0s - loss: 0.2875 - acc: 0.8978 - f1: 0.8778 - val_loss: 0.2167 - val_acc: 0.9506 - val_f1: 0.9226
# Epoch 26/1000
# 646/646 - 0s - loss: 0.2821 - acc: 0.8916 - f1: 0.8740 - val_loss: 0.2039 - val_acc: 0.9506 - val_f1: 0.9427
# Epoch 27/1000
# 646/646 - 0s - loss: 0.2383 - acc: 0.9164 - f1: 0.9008 - val_loss: 0.1935 - val_acc: 0.9506 - val_f1: 0.8949
# Epoch 28/1000
# 646/646 - 0s - loss: 0.2296 - acc: 0.9257 - f1: 0.8837 - val_loss: 0.1851 - val_acc: 0.9506 - val_f1: 0.9257
# Epoch 29/1000
# 646/646 - 0s - loss: 0.2045 - acc: 0.9396 - f1: 0.9281 - val_loss: 0.1759 - val_acc: 0.9506 - val_f1: 0.9583
# Epoch 30/1000
# 646/646 - 0s - loss: 0.2076 - acc: 0.9303 - f1: 0.9196 - val_loss: 0.1683 - val_acc: 0.9506 - val_f1: 0.9257
# Epoch 31/1000
# 646/646 - 0s - loss: 0.1941 - acc: 0.9319 - f1: 0.9221 - val_loss: 0.1623 - val_acc: 0.9506 - val_f1: 0.9574
# Epoch 32/1000
# 646/646 - 0s - loss: 0.2041 - acc: 0.9211 - f1: 0.9087 - val_loss: 0.1573 - val_acc: 0.9506 - val_f1: 0.9138
# Epoch 33/1000
# 646/646 - 0s - loss: 0.1916 - acc: 0.9288 - f1: 0.9178 - val_loss: 0.1529 - val_acc: 0.9506 - val_f1: 0.9376
# Epoch 34/1000
# 646/646 - 0s - loss: 0.1820 - acc: 0.9365 - f1: 0.9297 - val_loss: 0.1492 - val_acc: 0.9506 - val_f1: 0.9125
# Epoch 35/1000
# 646/646 - 0s - loss: 0.1569 - acc: 0.9458 - f1: 0.9388 - val_loss: 0.1461 - val_acc: 0.9506 - val_f1: 0.9425
# Epoch 36/1000
# 646/646 - 0s - loss: 0.1698 - acc: 0.9427 - f1: 0.9356 - val_loss: 0.1432 - val_acc: 0.9506 - val_f1: 0.9282
# Epoch 37/1000
# 646/646 - 0s - loss: 0.1577 - acc: 0.9427 - f1: 0.9142 - val_loss: 0.1423 - val_acc: 0.9506 - val_f1: 0.9257
# Epoch 38/1000
# 646/646 - 0s - loss: 0.1555 - acc: 0.9396 - f1: 0.9318 - val_loss: 0.1432 - val_acc: 0.9506 - val_f1: 0.9565
# Epoch 39/1000
# 646/646 - 0s - loss: 0.1619 - acc: 0.9365 - f1: 0.9283 - val_loss: 0.1425 - val_acc: 0.9506 - val_f1: 0.9565
# Validation accuracy: 0.9506173133850098, loss: 0.14254370193790505

# %% [markdown]
# #### Finally we can see the result of generating the spam comments. We achieved better F1-score with comparatively smoother line

# %% [markdown]
# #### Plotting and summarization of loss and accuracy -

# %%
# Plot the training loss and accuracy.

 
# Plot
N = len(h['loss'])
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, N), h["loss"], label="train_loss")
plt.plot(np.arange(0, N), h["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), h["acc"], label="train_acc")
plt.plot(np.arange(0, N), h["val_acc"], label="val_acc")
plt.plot(np.arange(0, N), h["f1"], label="train_f1-score")
plt.plot(np.arange(0, N), h["val_f1"], label="val_f1-score")
plt.title("Training Loss and Accuracy on Dataset")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")
plt.show()

# %% [markdown]
# ## Deriving the classification report with the help of the serialized model
#
# We have the model serialized in a .h5 file. We load it up and use it for evaluation and for making predictions.

# %%
# Loading the model

with CustomObjectScope({'GlorotUniform': glorot_uniform()}):
        model = load_model('zs_mlp_model.h5', custom_objects= {'f1': f1}) # We serialized the weights of the feed-forward network

# %% [markdown]
# We used `CustomObjectScope` to load up the `model.h5` file since there were compatibility issues. The `CustomObjectScope` needs an instance to be passed hence the use of the `gloroth_uniform` initializer. It does not have any other special purpose.
#
# Stackoverflow thread referred for this: https://stackoverflow.com/questions/53183865/unknown-initializer-glorotuniform-when-loading-keras-model

# %%
_, validation_vectors, _, cache = ngram_vectorize(
        list(X_train), np.array(y_train), list(X_valid))
valid_preds = model.predict_classes(validation_vectors)
print(classification_report(y_valid, valid_preds))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.99      0.96       101
#          1.0       0.98      0.89      0.93        61
#
#     accuracy                           0.95       162
#    macro avg       0.96      0.94      0.95       162
# weighted avg       0.95      0.95      0.95       162

# %%
confusion_matrix(y_valid, valid_preds)
# Out:
# array([[100,   1],
#        [  7,  54]], dtype=int64)

# %%
print('No. of spams in validation dataset: {}, No. of non-spams in vaidation dataset: {}'.format(y_valid.tolist().count(1.0), y_valid.tolist().count(0.0)))
# Out:
# No. of spams in validation dataset: 61, No. of non-spams in vaidation dataset: 101

# %%
testData = vectorizer.transform(np.array(['Get personalized training at Chennai, visit www.chennaimltraining.com']))
model.predict_classes(testData)
# Out:
# array([[1]])

# %% [markdown]
# ### Further considerations -
#
# * Hyperparameter tuning.
# * Prediction ensembles.
# * Build a simple REST API of the shallow net so that it can be deployed in production.
